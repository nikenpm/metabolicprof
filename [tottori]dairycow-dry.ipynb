# %%
# Import package
import pandas as pd
from scipy import stats
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
mpl.style.use('seaborn-whitegrid')
# Out:
# /Users/ohwadalab-mac/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/ohwadalab-mac/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/ohwadalab-mac/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
# Import dataset
df = pd.read_csv('./dairy-dry.csv',sep=',')

# %%
# Check dataset
df.head()
# Out:
#        global  cowid  days   TP  ALB   BUN  CHO  GOT  GGT    CA   IP  GLU  \
# 0  1482211717     38   -60  6.3  3.4  11.7   69   64   17  10.3  5.6   79
# 1   864141871     59   -49  7.4  3.7  11.7   68   68   21  10.4  6.1   76
# 2  1458511810     64   -47  6.1  3.8  11.1   48   58   21  10.0  6.6   73
# 3  1511310022     35   -45  7.4  3.4   9.3   82   62   24  10.6  5.6   73
# 4  1501270497     54   -43  6.4  3.5  10.2   60   62   20  10.6  5.6   70
#
#    NH3   NEFA    BHB
# 0  101  131.4  438.9
# 1  137   68.8  381.0
# 2  119  141.2  413.9
# 3  134  101.1  490.4
# 4  109  393.0  292.0

# %%
# Make copy of dataset
df_tr = df

# %%
# Standardize
# Calculate the z score of each value in the sample, 
# relative to the sample mean and standard deviation.
clmns = ['TP','ALB','BUN','GOT', 'GGT', 'CA','IP','GLU','NH3', 'NEFA','BHB']
df_tr_std = stats.zscore(df_tr[clmns])

# %%
# Deciding how many cluster using Elbow Method
sse = {}
for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, max_iter=1000).fit(df_tr)
    sse[k] = kmeans.inertia_ 
    # Inertia: Sum of distances of samples to their closest cluster center
plt.figure()
plt.plot(list(sse.keys()), list(sse.values()))
plt.xlabel("Number of cluster")
plt.ylabel("SSE")
plt.show()

# %%
# Check the Silhoutte Coefficient to confirm the number of cluster
# Generally, chooose n_cluster with highest score

from sklearn.metrics import silhouette_samples, silhouette_score

for n_cluster in range(2, 11):
    kmeans = KMeans(n_clusters=n_cluster).fit(df_tr)
    label = kmeans.labels_
    sil_coeff = silhouette_score(df_tr, label, metric='euclidean')
    print("For n_clusters={}, The Silhouette Coefficient is {}".format(n_cluster, sil_coeff))
# Out:
# For n_clusters=2, The Silhouette Coefficient is 0.9400680123836198
# For n_clusters=3, The Silhouette Coefficient is 0.6904626995340878
# For n_clusters=4, The Silhouette Coefficient is 0.6958776744845572
# For n_clusters=5, The Silhouette Coefficient is 0.7390720708781716
# For n_clusters=6, The Silhouette Coefficient is 0.7568923592732096
# For n_clusters=7, The Silhouette Coefficient is 0.7497932531636321
# For n_clusters=8, The Silhouette Coefficient is 0.803448012497663
# For n_clusters=9, The Silhouette Coefficient is 0.7955866152946738
# For n_clusters=10, The Silhouette Coefficient is 0.7867500024878341

# %%
# Implement k-means to standardized data 
kmeans = KMeans(n_clusters=3, random_state=0).fit(df_tr_std)
labels = kmeans.labels_

# %%
# After cluster is formed, add new column defining their cluster
df_tr['clusters'] = labels
clmns.extend(['clusters'])

# %%
# Check result of clustering
df_tr
# Out:
#         global  cowid  days   TP  ALB   BUN  CHO  GOT  GGT    CA   IP  GLU  \
# 0   1482211717     38   -60  6.3  3.4  11.7   69   64   17  10.3  5.6   79
# 1    864141871     59   -49  7.4  3.7  11.7   68   68   21  10.4  6.1   76
# 2   1458511810     64   -47  6.1  3.8  11.1   48   58   21  10.0  6.6   73
# 3   1511310022     35   -45  7.4  3.4   9.3   82   62   24  10.6  5.6   73
# 4   1501270497     54   -43  6.4  3.5  10.2   60   62   20  10.6  5.6   70
# 5    864142588     60   -42  6.4  3.3  13.1   49   62   20  10.2  8.2   74
# 6    864142632     57   -37  7.5  3.7  14.0  109   88   11  11.9  5.4   85
# 7    864207157     61   -37  6.4  3.5  13.5   65   53   20  10.7  4.6   72
# 8   1436725420     79   -35  6.4  3.5  12.9   66   54   22  10.5  7.4   68
# 9   1373724159     91   -34  7.3  3.9  12.5   78   72   19  11.4  3.3   81
# 10  1494659514     34   -31  6.5  3.5   9.5   76   52   19  10.5  7.1   73
# 11  1437612545     46   -31  6.4  3.3  10.1   67  105   16  10.1  4.5   72
# 12  1477034833     47   -31  7.0  3.6  10.9   70   62   21  10.4  6.5   60
# 13  1401416254     67   -28  6.3  3.5  11.1   68   56   13  10.2  6.1   71
# 14  1512209752     73   -27  6.8  3.8  11.6   53   73   14  10.5  5.7   72
# 15  1465611121     41   -26  6.2  3.5  12.5   83   65   16  10.8  5.9   69
# 16  1501556256     42   -26  6.9  3.4  11.5   55   73   27  10.2  6.3   72
# 17  1514410118     63   -24  6.9  3.8  12.0   93   71   22  11.6  4.7   85
# 18   864770057     62   -20  6.4  3.4  12.7   72   63   24  10.2  6.2   69
# 19  1461212865     87   -15  6.3  3.4   9.8   44   72   22  10.1  5.2   70
# 20   864142540     48   -15  6.9  3.8  12.8   49   66   15  10.4  5.7   77
# 21  1466606560     55   -10  6.1  3.6  12.1   84   68   22  10.4  6.0   66
# 22  1483811640     65   -10  5.6  3.6   9.9   48   58   23  10.4  6.2   73
# 23  1396615953     72    -9  6.1  3.5  10.4   46   65   13  10.3  4.8   70
# 24  1436725352     89    -9  6.1  3.6  10.3   46   69   22  10.3  6.1   70
# 25  1460912186     92    -6  6.3  3.5   9.5   63   68   14  10.2  5.7   70
#
#     NH3   NEFA    BHB  clusters
# 0   101  131.4  438.9         0
# 1   137   68.8  381.0         1
# 2   119  141.2  413.9         1
# 3   134  101.1  490.4         1
# 4   109  393.0  292.0         0
# 5   140  111.0  394.0         1
# 6   131  123.0  489.0         2
# 7   127  157.0  419.0         1
# 8   127  122.5  446.8         1
# 9   149  112.0  501.0         2
# 10  124  137.5  549.9         1
# 11  130  158.4  406.1         0
# 12  124   84.7  568.5         1
# 13  104   95.1  455.2         0
# 14   98  211.2  405.1         0
# 15  111  196.7  383.1         0
# 16  128  146.8  488.6         1
# 17  126  105.8  468.6         2
# 18  114   75.0  512.0         1
# 19  116  121.9  426.3         0
# 20  133  154.0  524.0         1
# 21  122  124.0  537.0         1
# 22   91  226.0  532.7         0
# 23  104  268.1  508.0         0
# 24  120  123.9  502.2         1
# 25  104  326.0  587.0         0

# %%
# If needed, save clustering result
# df_tr.to_csv('./cluster-dairy-dry.csv')

# %%
# Calculate mean of each cluster
mean = df_tr[clmns].groupby(['clusters']).mean()
mean
# Out:
#                 TP       ALB        BUN        GOT        GGT         CA  \
# clusters
# 0         6.270000  3.500000  10.680000  68.800000  16.800000  10.350000
# 1         6.615385  3.546154  11.646154  62.307692  21.384615  10.369231
# 2         7.233333  3.800000  12.833333  77.000000  17.333333  11.633333
#
#                 IP        GLU         NH3        NEFA         BHB
# clusters
# 0         5.530000  71.600000  106.800000  212.780000  443.440000
# 1         6.338462  71.000000  126.846154  119.038462  479.023077
# 2         4.466667  83.666667  135.333333  113.600000  486.200000

# %%
# If needed, save mean result
# mean.to_csv('./meanbefore.csv')

# %%
# Calculate standard deviation of each cluster
std = df_tr[clmns].groupby(['clusters']).std()
std
# Out:
#                 TP       ALB       BUN        GOT       GGT        CA  \
# clusters
# 0         0.298329  0.133333  0.988602  13.814646  3.675746  0.227303
# 1         0.459794  0.156074  1.371505   6.575011  2.844247  0.188788
# 2         0.305505  0.100000  1.040833   9.539392  5.686241  0.251661
#
#                 IP       GLU        NH3       NEFA        BHB
# clusters
# 0         0.545792  2.875181  10.695794  94.564379  83.424433
# 1         0.889324  4.509250   7.526023  29.375600  61.899962
# 2         1.069268  2.309401  12.096832   8.710913  16.380476

# %%
# If needed, save stdev result
# std.to_csv('./std1.csv')

# %%
# Plot 1: Relationship between Calcium and Phosphorus within each cluster

ax = sns.lmplot('CA', 'IP', 
          data=df_tr, 
         fit_reg=False, 
        hue="clusters",  palette="Set1",
       scatter_kws={"marker": "D", 
                   "s": 50})

plt.title('Calcium vs Phosporus (Mineral Metabolism)')
plt.xlabel('CA')
plt.ylabel('IP')
# Out:
# Text(23.72127604166667, 0.5, 'IP')

# %%
# Plot 2: 3D - plot between NEFA, GLU, and BHB within each cluster

import matplotlib as mpl 
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
mpl.style.use('seaborn-whitegrid')

fig = plt.figure(figsize=(8, 7))
ax1 = fig.add_subplot(111,projection='3d')

colors = ['red', 'blue', 'green']
for i in range(len(df_tr)):
    x, y, z = df_tr.iloc[i]['BHB'], df_tr.iloc[i]['NEFA'], df_tr.iloc[i]['GLU']
    ax1.scatter(x, y, z, c=colors[int(df_tr.iloc[i]['clusters'])], alpha = 0.6, linewidths=4, label = 'clusters')
    ax1.text(x, y, z, '{0}'.format(df_tr.iloc[i]['cowid'].astype(int)),va='bottom', size=10)
 
    
ax1.set_xlabel('BHB')
ax1.set_ylabel('NEFA')
ax1.set_zlabel('GLU')

plt.title('Clusters in dry period related to Energy Balance')    
plt.show()

# For view from different angle
#for angle in range(0, 360):
#    ax1.view_init(10, angle)
#    plt.draw()
#    plt.pause(.001)

# %%
# Plot 3: 3D - plot between Total Protein, ALB, and BUN within each cluster

import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
mpl.style.use('seaborn-whitegrid')

fig = plt.figure(figsize=(8, 7))
ax1 = fig.add_subplot(111,projection='3d')

colors = ['red', 'blue', 'green']
for i in range(len(df_tr)):
    x, y, z = df_tr.iloc[i]['TP'], df_tr.iloc[i]['ALB'], df_tr.iloc[i]['BUN']
    ax1.scatter(x, y, z, c=colors[int(df_tr.iloc[i]['clusters'])], alpha = 0.6, linewidths=4)
    ax1.text(x, y, z, '{0}'.format(df_tr.iloc[i]['cowid'].astype(int)),va='bottom', size=10)
 
    
ax1.set_xlabel('TP')
ax1.set_ylabel('ALB')
ax1.set_zlabel('BUN')

plt.title('Clusters in dry period related to Protein Status')   
plt.show()

# For view from different angle
#for angle in range(0, 360):
#       ax1.view_init(10, angle)
#       plt.draw()
#       plt.pause(.001)

# %%
# Plot 4: 3D - plot between GOT, GGT, and NH3 within each cluster
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
mpl.style.use('seaborn-whitegrid')

fig = plt.figure(figsize=(8, 7))
ax1 = fig.add_subplot(111,projection='3d')

colors = ['red', 'blue', 'green']
for i in range(len(df_tr)):
    x, y, z = df_tr.iloc[i]['GOT'], df_tr.iloc[i]['GGT'], df_tr.iloc[i]['NH3']
    ax1.scatter(x, y, z, c=colors[int(df_tr.iloc[i]['clusters'])], alpha = 0.6, linewidths=4)
    ax1.text(x, y, z, '{0}'.format(df_tr.iloc[i]['cowid'].astype(int)),ha='right', size=10)
    
    
ax1.set_xlabel('GOT')
ax1.set_ylabel('GGT')
ax1.set_zlabel('NH3')


plt.title('Clusters in dry period related to Liver Condition')      
#plt.show()

# For view from different angle
#for angle in range(0, 360):
#       ax1.view_init(10, angle)
#       plt.draw()
#       plt.pause(.001)
# Out:
# Text(0.5, 0.92, 'Clusters in dry period related to Liver Condition')

# %%
# Pair plot to see relationship between 2 metabolites
energy = df_tr[['BHB', 'NEFA', 'GLU','clusters']]

sns.pairplot(energy, kind="scatter",  diag_kind="hist", hue="clusters", markers=["o", "o"], palette="Set1")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-a186e73404eb> in <module>()
#       2 energy = df_tr[['BHB', 'NEFA', 'GLU','clusters']]
#       3
# ----> 4 sns.pairplot(energy, kind="scatter",  diag_kind="hist", hue="clusters", markers=["o", "o"], palette="Set1")
#       5 plt.show()
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, size, aspect, dropna, plot_kws, diag_kws, grid_kws)
#    2051             markers = [markers] * n_markers
#    2052         if len(markers) != n_markers:
# -> 2053             raise ValueError(("markers must be a singleton or a list of "
#    2054                               "markers for each level of the hue variable"))
#    2055         grid.hue_kws = {"marker": markers}
#
# ValueError: markers must be a singleton or a list of markers for each level of the hue variable

# %%
pro = df_tr[['TP', 'BUN', 'ALB','clusters']]

sns.pairplot(pro, kind="scatter",  diag_kind="hist", hue="clusters", markers=["o", "o"], palette="Set1")
plt.show()

# %%
liver = df_tr[['NH3', 'GGT', 'GOT','clusters']]

sns.pairplot(liver, kind="scatter",  diag_kind="hist", hue="clusters", markers=["o", "o"], palette="Set1")
plt.show()

# %%
df_tr

# %%
# Sort the dataframe by clusters
df_tr = df.sort_values(by="clusters")

# %%
def color_protein(value):
    if value < 6:
        color = 'red'
    elif 6.8 < value or value > 8.5:
        color = 'green'
    else:
        color = 'black'

    return 'color: %s' % color

# %%
def color_alb(value):
    if value < 3:
        color = 'red'
    elif value > 3.7:
        color = 'green'
    else:
        color = 'black'

    return 'color: %s' % color

# %%
def color_bun(value):
    if value < 13:
        color = 'red'
    elif value > 17:
        color = 'green'
    else:
        color = 'black'

    return 'color: %s' % color

# %%
def color_nefa(value):
    if value > 700:
        color = 'red'
    elif value < 300:
        color = 'green'
    else:
        color = 'black'

    return 'color: %s' % color

# %%
def color_glu(value):
    if value < 42:
        color = 'red'
    elif value > 74:
        color = 'green'
    else:
        color = 'black'

    return 'color: %s' % color

# %%
def color_ggt(value):
    if value > 27:
        color = 'red'
    elif  value < 15 or value > 19:
        color = 'green'
    else:
        color = 'black'

    return 'color: %s' % color

# %%
def color_ca(value):
    if value < 8:
        color = 'red'
    elif value > 11:
        color = 'green'
    else:
        color = 'black'

    return 'color: %s' % color

# %%
def color_ip(value):
    if value < 3.5:
        color = 'red'
    elif value > 8:
        color = 'green'
    else:
        color = 'black'

    return 'color: %s' % color

# %%
def color_bhb(value):
    if value > 960:
        color = 'red'
    elif value < 120:
        color = 'green'
    else:
        color = 'black'

    return 'color: %s' % color

# %%
def color_got(value):
    if value > 100:
        color = 'red'
    else:
        color = 'black'

    return 'color: %s' % color

# %%
new_df = df_tr.drop(columns=['CHO'])

# %%
# Map individual data based on metabolites score limit

new_df.style.\
    applymap(color_protein, subset=['TP']).\
    applymap(color_alb, subset=['ALB']).\
    applymap(color_nefa, subset=['NEFA']).\
    applymap(color_ggt, subset=['GGT']).\
    applymap(color_ca, subset=['CA']).\
    applymap(color_ip, subset=['IP']).\
    applymap(color_glu, subset=['GLU']).\
    applymap(color_bhb, subset=['BHB']).\
    applymap(color_got, subset=['GOT']).\
    applymap(color_bun, subset=['BUN']).\
    to_excel('dairydry.xlsx', engine='openpyxl') #File save to excel

# %%
def main():
    pro = df_tr["global"][(df_tr["TP"] < 6) | (df_tr["BUN"] < 13) | (df_tr["ALB"] < 3)].tolist()
    eb = df_tr["global"][(df_tr["NEFA"] > 700)| (df_tr["GLU"] < 42) | (df_tr["BHB"] > 960) ].tolist()
    liver = df_tr["global"][(df_tr["GOT"] > 100) | (df_tr["GGT"] > 27)].tolist()
    caip = df_tr["global"][(df_tr["CA"] < 8) | (df_tr["IP"] < 3.5)].tolist()
    
    
    print("Cow ID that need monitoring of protein status:", pro)
    print("Cow ID who needs monitoring of energy balance / stress:", eb)
    print("Cow ID that need monitoring of liver status:", liver)
    print("Cow ID that need monitoring of Calcium/Phosphorus status:", caip)
    
if __name__ == "__main__":
    main()
# Out:
# Cow ID that need monitoring of protein status: [1482211717, 1396615953, 1483811640, 1461212865, 1465611121, 1512209752, 1401416254, 1437612545, 1460912186, 1501270497, 1477034833, 1494659514, 1436725352, 864141871, 1501556256, 1436725420, 864770057, 1511310022, 864142540, 1466606560, 1458511810, 1373724159, 1514410118]
# Cow ID who needs monitoring of energy balance / stress: []
# Cow ID that need monitoring of liver status: [1437612545]
# Cow ID that need monitoring of Calcium/Phosphorus status: [1373724159]

# %%
df_tr
# Out:
#         global  cowid  days   TP  ALB   BUN  CHO  GOT  GGT    CA   IP  GLU  \
# 0   1482211717     38   -60  6.3  3.4  11.7   69   64   17  10.3  5.6   79
# 23  1396615953     72    -9  6.1  3.5  10.4   46   65   13  10.3  4.8   70
# 22  1483811640     65   -10  5.6  3.6   9.9   48   58   23  10.4  6.2   73
# 19  1461212865     87   -15  6.3  3.4   9.8   44   72   22  10.1  5.2   70
# 15  1465611121     41   -26  6.2  3.5  12.5   83   65   16  10.8  5.9   69
# 14  1512209752     73   -27  6.8  3.8  11.6   53   73   14  10.5  5.7   72
# 13  1401416254     67   -28  6.3  3.5  11.1   68   56   13  10.2  6.1   71
# 11  1437612545     46   -31  6.4  3.3  10.1   67  105   16  10.1  4.5   72
# 25  1460912186     92    -6  6.3  3.5   9.5   63   68   14  10.2  5.7   70
# 4   1501270497     54   -43  6.4  3.5  10.2   60   62   20  10.6  5.6   70
# 12  1477034833     47   -31  7.0  3.6  10.9   70   62   21  10.4  6.5   60
# 10  1494659514     34   -31  6.5  3.5   9.5   76   52   19  10.5  7.1   73
# 7    864207157     61   -37  6.4  3.5  13.5   65   53   20  10.7  4.6   72
# 24  1436725352     89    -9  6.1  3.6  10.3   46   69   22  10.3  6.1   70
# 1    864141871     59   -49  7.4  3.7  11.7   68   68   21  10.4  6.1   76
# 5    864142588     60   -42  6.4  3.3  13.1   49   62   20  10.2  8.2   74
# 16  1501556256     42   -26  6.9  3.4  11.5   55   73   27  10.2  6.3   72
# 8   1436725420     79   -35  6.4  3.5  12.9   66   54   22  10.5  7.4   68
# 18   864770057     62   -20  6.4  3.4  12.7   72   63   24  10.2  6.2   69
# 3   1511310022     35   -45  7.4  3.4   9.3   82   62   24  10.6  5.6   73
# 20   864142540     48   -15  6.9  3.8  12.8   49   66   15  10.4  5.7   77
# 21  1466606560     55   -10  6.1  3.6  12.1   84   68   22  10.4  6.0   66
# 2   1458511810     64   -47  6.1  3.8  11.1   48   58   21  10.0  6.6   73
# 9   1373724159     91   -34  7.3  3.9  12.5   78   72   19  11.4  3.3   81
# 6    864142632     57   -37  7.5  3.7  14.0  109   88   11  11.9  5.4   85
# 17  1514410118     63   -24  6.9  3.8  12.0   93   71   22  11.6  4.7   85
#
#     NH3   NEFA    BHB  clusters
# 0   101  131.4  438.9         0
# 23  104  268.1  508.0         0
# 22   91  226.0  532.7         0
# 19  116  121.9  426.3         0
# 15  111  196.7  383.1         0
# 14   98  211.2  405.1         0
# 13  104   95.1  455.2         0
# 11  130  158.4  406.1         0
# 25  104  326.0  587.0         0
# 4   109  393.0  292.0         0
# 12  124   84.7  568.5         1
# 10  124  137.5  549.9         1
# 7   127  157.0  419.0         1
# 24  120  123.9  502.2         1
# 1   137   68.8  381.0         1
# 5   140  111.0  394.0         1
# 16  128  146.8  488.6         1
# 8   127  122.5  446.8         1
# 18  114   75.0  512.0         1
# 3   134  101.1  490.4         1
# 20  133  154.0  524.0         1
# 21  122  124.0  537.0         1
# 2   119  141.2  413.9         1
# 9   149  112.0  501.0         2
# 6   131  123.0  489.0         2
# 17  126  105.8  468.6         2

# %%
# Sort the dataframe by clusters
df_tr = df.sort_values(by="clusters")

# %%
df_tr
# Out:
#         global  cowid  days   TP  ALB   BUN  CHO  GOT  GGT    CA   IP  GLU  \
# 0   1482211717     38   -60  6.3  3.4  11.7   69   64   17  10.3  5.6   79
# 23  1396615953     72    -9  6.1  3.5  10.4   46   65   13  10.3  4.8   70
# 22  1483811640     65   -10  5.6  3.6   9.9   48   58   23  10.4  6.2   73
# 19  1461212865     87   -15  6.3  3.4   9.8   44   72   22  10.1  5.2   70
# 15  1465611121     41   -26  6.2  3.5  12.5   83   65   16  10.8  5.9   69
# 14  1512209752     73   -27  6.8  3.8  11.6   53   73   14  10.5  5.7   72
# 13  1401416254     67   -28  6.3  3.5  11.1   68   56   13  10.2  6.1   71
# 11  1437612545     46   -31  6.4  3.3  10.1   67  105   16  10.1  4.5   72
# 25  1460912186     92    -6  6.3  3.5   9.5   63   68   14  10.2  5.7   70
# 4   1501270497     54   -43  6.4  3.5  10.2   60   62   20  10.6  5.6   70
# 12  1477034833     47   -31  7.0  3.6  10.9   70   62   21  10.4  6.5   60
# 10  1494659514     34   -31  6.5  3.5   9.5   76   52   19  10.5  7.1   73
# 7    864207157     61   -37  6.4  3.5  13.5   65   53   20  10.7  4.6   72
# 24  1436725352     89    -9  6.1  3.6  10.3   46   69   22  10.3  6.1   70
# 1    864141871     59   -49  7.4  3.7  11.7   68   68   21  10.4  6.1   76
# 5    864142588     60   -42  6.4  3.3  13.1   49   62   20  10.2  8.2   74
# 16  1501556256     42   -26  6.9  3.4  11.5   55   73   27  10.2  6.3   72
# 8   1436725420     79   -35  6.4  3.5  12.9   66   54   22  10.5  7.4   68
# 18   864770057     62   -20  6.4  3.4  12.7   72   63   24  10.2  6.2   69
# 3   1511310022     35   -45  7.4  3.4   9.3   82   62   24  10.6  5.6   73
# 20   864142540     48   -15  6.9  3.8  12.8   49   66   15  10.4  5.7   77
# 21  1466606560     55   -10  6.1  3.6  12.1   84   68   22  10.4  6.0   66
# 2   1458511810     64   -47  6.1  3.8  11.1   48   58   21  10.0  6.6   73
# 9   1373724159     91   -34  7.3  3.9  12.5   78   72   19  11.4  3.3   81
# 6    864142632     57   -37  7.5  3.7  14.0  109   88   11  11.9  5.4   85
# 17  1514410118     63   -24  6.9  3.8  12.0   93   71   22  11.6  4.7   85
#
#     NH3   NEFA    BHB  clusters
# 0   101  131.4  438.9         0
# 23  104  268.1  508.0         0
# 22   91  226.0  532.7         0
# 19  116  121.9  426.3         0
# 15  111  196.7  383.1         0
# 14   98  211.2  405.1         0
# 13  104   95.1  455.2         0
# 11  130  158.4  406.1         0
# 25  104  326.0  587.0         0
# 4   109  393.0  292.0         0
# 12  124   84.7  568.5         1
# 10  124  137.5  549.9         1
# 7   127  157.0  419.0         1
# 24  120  123.9  502.2         1
# 1   137   68.8  381.0         1
# 5   140  111.0  394.0         1
# 16  128  146.8  488.6         1
# 8   127  122.5  446.8         1
# 18  114   75.0  512.0         1
# 3   134  101.1  490.4         1
# 20  133  154.0  524.0         1
# 21  122  124.0  537.0         1
# 2   119  141.2  413.9         1
# 9   149  112.0  501.0         2
# 6   131  123.0  489.0         2
# 17  126  105.8  468.6         2

# %%
df_tr.style.\
    applymap(color_protein, subset=['TP']).\
    applymap(color_alb, subset=['ALB']).\
    applymap(color_nefa, subset=['NEFA']).\
    applymap(color_ggt, subset=['GGT']).\
    applymap(color_ca, subset=['CA']).\
    applymap(color_ip, subset=['IP']).\
    applymap(color_glu, subset=['GLU']).\
    applymap(color_bhb, subset=['BHB']).\
    applymap(color_got, subset=['GOT']).\
    applymap(color_bun, subset=['BUN'])#.\
   # to_excel('dairydry.xlsx', engine='openpyxl') #File save to excel
# Out:
# <style  type="text/css" >
#     #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row0_col3 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row0_col4 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row0_col5 {
#             color:  red;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row0_col7 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row0_col8 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row0_col9 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row0_col10 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row0_col11 {
#             color:  green;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row0_col13 {
#             color:  green;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row0_col14 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row1_col3 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row1_col4 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row1_col5 {
#             color:  red;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row1_col7 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row1_col8 {
#             color:  green;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row1_col9 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row1_col10 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row1_col11 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row1_col13 {
#             color:  green;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row1_col14 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row2_col3 {
#             color:  red;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row2_col4 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row2_col5 {
#             color:  red;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row2_col7 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row2_col8 {
#             color:  green;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row2_col9 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row2_col10 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row2_col11 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row2_col13 {
#             color:  green;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row2_col14 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row3_col3 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row3_col4 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row3_col5 {
#             color:  red;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row3_col7 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row3_col8 {
#             color:  green;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row3_col9 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row3_col10 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row3_col11 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row3_col13 {
#             color:  green;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row3_col14 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row4_col3 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row4_col4 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row4_col5 {
#             color:  red;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row4_col7 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row4_col8 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row4_col9 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row4_col10 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row4_col11 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row4_col13 {
#             color:  green;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row4_col14 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row5_col3 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row5_col4 {
#             color:  green;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row5_col5 {
#             color:  red;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row5_col7 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row5_col8 {
#             color:  green;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row5_col9 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row5_col10 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row5_col11 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row5_col13 {
#             color:  green;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row5_col14 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row6_col3 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row6_col4 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row6_col5 {
#             color:  red;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row6_col7 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row6_col8 {
#             color:  green;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row6_col9 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row6_col10 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row6_col11 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row6_col13 {
#             color:  green;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row6_col14 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row7_col3 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row7_col4 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row7_col5 {
#             color:  red;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row7_col7 {
#             color:  red;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row7_col8 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row7_col9 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row7_col10 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row7_col11 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row7_col13 {
#             color:  green;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row7_col14 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row8_col3 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row8_col4 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row8_col5 {
#             color:  red;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row8_col7 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row8_col8 {
#             color:  green;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row8_col9 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row8_col10 {
#             color:  black;
#         }    #T_da2c92e4_2a8a_11e9_ada5_a860b62da5a8row

# %%
def main():
    pro = df_tr["global"][(df_tr["TP"] < 6) | (df_tr["BUN"] < 13) | (df_tr["ALB"] < 3)].tolist()
    eb = df_tr["global"][(df_tr["NEFA"] > 700)| (df_tr["GLU"] < 42) | (df_tr["BHB"] > 960) ].tolist()
    liver = df_tr["global"][(df_tr["GOT"] > 100) | (df_tr["GGT"] > 27)].tolist()
    caip = df_tr["global"][(df_tr["CA"] < 8) | (df_tr["IP"] < 3.5)].tolist()
        
    print("Cow ID that need monitoring of protein status:", pro)
    print("Cow ID who needs monitoring of energy balance / stress:", eb)
    print("Cow ID that need monitoring of liver status:", liver)
    print("Cow ID that need monitoring of Calcium/Phosphorus status:", caip)
    
if __name__ == "__main__":
    main()

# %%
pro = df_tr["global"][(df_tr["TP"] < 6) | (df_tr["BUN"] < 13) | (df_tr["ALB"] < 3)]

# %%
pro
# Out:
# [1482211717,
#  1396615953,
#  1483811640,
#  1461212865,
#  1465611121,
#  1512209752,
#  1401416254,
#  1437612545,
#  1460912186,
#  1501270497,
#  1477034833,
#  1494659514,
#  1436725352,
#  864141871,
#  1501556256,
#  1436725420,
#  864770057,
#  1511310022,
#  864142540,
#  1466606560,
#  1458511810,
#  1373724159,
#  1514410118]

# %%
def main():
    cluster0= df_tr["global"][(df_tr["clusters"] == 0)].tolist()
    cluster1= df_tr["global"][(df_tr["clusters"] == 1)].tolist()
    cluster2= df_tr["global"][(df_tr["clusters"] == 2)].tolist()
    nc0 = len(df_tr[(df_tr['clusters']==0)])
    nc1 = len(df_tr[(df_tr['clusters']==1)])
    nc2 = len(df_tr[(df_tr['clusters']==2)])
    
    cnteb = len(df_tr[(df_tr['clusters'] == 0) & ((df_tr["NEFA"] > 700)| (df_tr["GLU"] < 42) | (df_tr["BHB"] > 960))])
    cntpro = len(df_tr[(df_tr['clusters'] == 0) & ((df_tr["TP"] < 6)| (df_tr["BUN"] < 13) | (df_tr["ALB"] < 3))])
    cntgot = len(df_tr[(df_tr['clusters'] == 0) & ((df_tr["GOT"] > 100)| (df_tr["GGT"] > 27))])
    cntca = len(df_tr[(df_tr['clusters'] == 0) & ((df_tr["CA"] < 8) | (df_tr["IP"] < 3.5))])
    
    cnteb1 = len(df_tr[(df_tr['clusters'] == 1) & ((df_tr["NEFA"] > 700)| (df_tr["GLU"] < 42) | (df_tr["BHB"] > 960))])
    cntpro1 = len(df_tr[(df_tr['clusters'] == 1) & ((df_tr["TP"] < 6)| (df_tr["BUN"] < 13) | (df_tr["ALB"] < 3))])
    cntgot1 = len(df_tr[(df_tr['clusters'] == 1) & ((df_tr["GOT"] > 100)| (df_tr["GGT"] > 27))])
    cntca1 = len(df_tr[(df_tr['clusters'] == 1) & ((df_tr["CA"] < 8) | (df_tr["IP"] < 3.5))])
    
    cnteb2 = len(df_tr[(df_tr['clusters'] == 2) & ((df_tr["NEFA"] > 700)| (df_tr["GLU"] < 42) | (df_tr["BHB"] > 960))])
    cntpro2 = len(df_tr[(df_tr['clusters'] == 2) & ((df_tr["TP"] < 6)| (df_tr["BUN"] < 13) | (df_tr["ALB"] < 3))])
    cntgot2 = len(df_tr[(df_tr['clusters'] == 2) & ((df_tr["GOT"] > 100)| (df_tr["GGT"] > 27))])
    cntca2 = len(df_tr[(df_tr['clusters'] == 2) & ((df_tr["CA"] < 8) | (df_tr["IP"] < 3.5))])
    
    print("Cluster 0 have", nc0, "cows with ID:", cluster0)
    if cntpro > 0.7* nc0:
        print ("Food and diet shoud be monitored because protein is out of range.")
    else:
        print ("Protein status is good.")    
    if cntgot > 0.7 * nc0:
        print ("Liver condition should be monitored in next 4-6 weeks because liver value is out of range, glucose infusion can be considered.")
    else:
        print ("Liver condition is in good condition.")    
    if cnteb > 0.7*nc0:
        print ("Cow is under stress situation, energy balance is out of range")
    else :
        print("Energy balance is in good condition.")
    if cntca > 0.7*nc0:
        print ("Cow has high calcium diet demand.")
    else :
        print("Calcium and phosporus is in good condition.")
    print("---")
    print("Cluster 1 have", nc1, "cows with ID:", cluster1)
    if cntpro1 > 0.7* nc1:
        print ("Food and diet shoud be monitored because protein is out of range.")
    else:
        print ("Protein status is good.")    
    if cntgot1 > 0.7 * nc1:
        print ("Liver condition should be monitored in next 4-6 weeks because liver value is out of range, glucose infusion can be considered.")
    else:
        print ("Liver condition is in good condition.")    
    if cnteb1 > 0.7*nc1:
        print ("Cow is under stress situation, energy balance is out of range")
    else :
        print("Energy balance is in good condition.")
    if cntca1 > 0.7*nc1:
        print ("Cow has high calcium diet demand.")
    else :
        print("Calcium and phosporus is in good condition.")
    print("---")
    print("Cluster 2 have", nc2, "cows with ID:", cluster2)
    if cntpro2 > 0.7* nc2:
        print ("Food and diet shoud be monitored because protein is out of range.")
    else:
        print ("Protein status is in good condition.")    
    if cntgot2 > 0.7 * nc2:
        print ("Liver condition should be monitored in next 4-6 weeks because liver value is out of range, glucose infusion can be considered.")
    else:
        print ("Liver condition is in good condition.")    
    if cnteb2 > 0.7*nc2:
        print ("Cow is under stress situation, energy balance is out of range")
    else :
        print("Energy balance is in good condition.")
    if cntca2 > 0.7*nc1:
        print ("Cow has high calcium diet demand.")
    else :
        print("Calcium and phosporus is in good condition.")
    print("---")

if __name__ == "__main__":
    main()
# Out:
# Cluster 0 have 10 cows with ID: [1482211717, 1396615953, 1483811640, 1461212865, 1465611121, 1512209752, 1401416254, 1437612545, 1460912186, 1501270497]
# Food and diet shoud be monitored because protein is out of range.
# Liver condition is in good condition.
# Energy balance is in good condition.
# Calcium and phosporus is in good condition.
# ---
# Cluster 1 have 13 cows with ID: [1477034833, 1494659514, 864207157, 1436725352, 864141871, 864142588, 1501556256, 1436725420, 864770057, 1511310022, 864142540, 1466606560, 1458511810]
# Food and diet shoud be monitored because protein is out of range.
# Liver condition is in good condition.
# Energy balance is in good condition.
# Calcium and phosporus is in good condition.
# ---
# Cluster 2 have 3 cows with ID: [1373724159, 864142632, 1514410118]
# Protein status is in good condition.
# Liver condition is in good condition.
# Energy balance is in good condition.
# Calcium and phosporus is in good condition.
# ---
